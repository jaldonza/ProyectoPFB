# %%
import pandas as pd
import yfinance as yf
from datetime import datetime

# %%
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
table = pd.read_html(url)[0]  
sp500_tickers = table[['Symbol', 'Security']]  

all_data = pd.DataFrame()

start_date = '2000-01-01'
end_date = '2024-09-30'

for index, row in sp500_tickers.iterrows():
    ticker = row['Symbol']
    company = row['Security']


    stock_data = yf.download(ticker, start=start_date, end=end_date)

 
    stock_data['ticker'] = ticker
    stock_data['Company'] = company

    
    all_data = pd.concat([all_data, stock_data])

all_data.to_csv('sp500_historial_data_2000_2024.csv', index=True)

# %%
df = pd.read_csv('sp500_historial_data_2000_2024.csv')

df.head(50)
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2000-01-03  40.159908  40.342808  39.323788  39.454430  19.813831
# 1   2000-01-04  38.827339  39.637333  37.886707  37.886707  19.026533
# 2   2000-01-05  38.095737  40.238293  38.095737  38.984116  19.577646
# 3   2000-01-06  39.428303  42.851170  39.428303  42.119564  21.152258
# 4   2000-01-07  42.276337  43.399876  41.779892  42.955685  21.572138
# 5   2000-01-10  41.988922  43.269230  41.806019  42.746655  21.467182
# 6   2000-01-11  42.119564  42.851170  42.015049  42.015049  21.099771
# 7   2000-01-12  42.616013  43.321487  42.119564  42.119564  21.152258
# 8   2000-01-13  42.354725  42.589882  41.962791  42.119564  21.152258
# 9   2000-01-14  42.119564  42.197952  41.361832  41.518604  20.850452
# 10  2000-01-18  40.656357  41.492474  40.604095  40.604095  20.391193
# 11  2000-01-19  40.865383  41.779892  40.865383  41.309574  20.745495
# ...
